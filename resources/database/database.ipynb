# %%
import pandas as pd

# %%
db = pd.read_csv('database.csv')

# %%
db.head()
# Out:
#                                                title  \
# 0  [Communication interventriculaire compliquant ...
# 1  Outcomes of atrioventricular septal defects wi...
# 2  An Unexpected Diagnostic Twist in an Elderly P...
# 3  Pulmonary Artery Dilatation Due to Pressure or...
# 4  Perioperative sildenafil therapy in pulmonary ...
#
#                                          authors_str  \
# 0  Lamine H; Farhati A; Bouzidi H; Saidane S; Zai...
# 1       Aly S; Qattea I; Othman H; Nguyen HH; Aly HZ
# 2  Vysočanský S; Luknár M; Lesný P; Poláková-Mišt...
# 3  Kaldararova M; Bobocka K; Kantorova A; Drangov...
# 4  Usmani SUR; Hasan SU; Ali SH; Ahmed SH; Pervez...
#
#                             doi  \
# 0  10.1016/j.ancard.2023.101718
# 1     10.1017/S1047951123003116
# 2          10.7759/cureus.55971
# 3           10.3390/jcm13061567
# 4  10.1016/j.asjsur.2024.03.003
#
#                                             abstract      pmid  score  \
# ...

# %%
db['translated'] = False

# %%
db.head()
# Out:
#                                                title  \
# 0  [Communication interventriculaire compliquant ...
# 1  Outcomes of atrioventricular septal defects wi...
# 2  An Unexpected Diagnostic Twist in an Elderly P...
# 3  Pulmonary Artery Dilatation Due to Pressure or...
# 4  Perioperative sildenafil therapy in pulmonary ...
#
#                                          authors_str  \
# 0  Lamine H; Farhati A; Bouzidi H; Saidane S; Zai...
# 1       Aly S; Qattea I; Othman H; Nguyen HH; Aly HZ
# 2  Vysočanský S; Luknár M; Lesný P; Poláková-Mišt...
# 3  Kaldararova M; Bobocka K; Kantorova A; Drangov...
# 4  Usmani SUR; Hasan SU; Ali SH; Ahmed SH; Pervez...
#
#                             doi  \
# 0  10.1016/j.ancard.2023.101718
# 1     10.1017/S1047951123003116
# 2          10.7759/cureus.55971
# 3           10.3390/jcm13061567
# 4  10.1016/j.asjsur.2024.03.003
#
#                                             abstract      pmid  score  \
# ...

# %%
db.to_csv('database_translated', index=False)
